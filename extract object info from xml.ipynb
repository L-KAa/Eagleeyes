# %%
import os
from glob import glob # extract path of each file
import pandas as pd # data preprocessing
from xml.etree import ElementTree as et # parse information from XML
from functools import reduce

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# step-1: get path of each xml file
xmlfiles = glob('/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/*.xml')
# replace \\ with /
replace_text = lambda x: x.replace('\\','/')
xmlfiles = list(map(replace_text,xmlfiles))

# %%
xmlfiles
# Out:
# ['/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/36_jpg.rf.e4757f0ab57054029ade0bb5d666673a.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/KakaoTalk_20221018_001425789_07_jpg.rf.afa1e8ac8ff8cbd3a5686e56511885da.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/feliz-administrador-de-almacen-pie-en-una-fabrica-con-casco-blanco-y-chaleco-seguridad-naranja-mirando-la-sonrisa-camara-173591370_jpg.rf.1ca9470ab4c46ac6d52ed134fb13258e.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/WhatsApp-Image-2023-10-10-at-11-18-26_a11a66e1_jpg.rf.4aba94595630757ac4a4a4f63127c555.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/00000206_jpg.rf.3421fc09104c3afc6e8cbb3bc5a9a8c9.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/images-31-.rf.0211bd26e06fb898b7c48989199ceabd.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/Video1_228_jpg.rf.a4b27b89f18bd7141f1ca2373d10e49f.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/download-1-_jpeg_jpg.rf.c18c60706e23ebf67126dc0c4eef7169.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/087206443-zoom-out-construction-workers-_jpg.rf.6032cb997c9ff3a1b08e32ee5607c6d2.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/attractive-worker-reflector-vest-young-beautiful-girl-protective-helmet-construction-tablet-hands-white-38704621_jpg.rf.298d0ebeb0fb64a422439bfb888fd7b5.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/35_jpg.rf.2deaf3f7a0cc1d868d223a54c91a8307.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/00000258_jpg.rf.4aa646b73148aa0f41fc2419b14b1fe5.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/087071347-construction-site-manager-givi_jpg.rf.dc8a1b2b2edd1b555780d6c9114b681a.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/00000066_jpg.rf.2511b5f14d807c998e668476c78395cb.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/33_jpg.rf.93ced91abb94382f0eeb048efd611e37.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/00000216_jpg.rf.de216a4215ab9441aa5d42ba41dde39c.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/ppe_0185_jpg-rf2_jpg.rf.17313d8e2a9087bbfb34a1aa5c42ae23.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/00000289_jpg.rf.94236b220f4caefa4f05b01159af6db9.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/images-8-_jpg.rf.b3271257604f2ecff9d9320acc889082.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/img_03.rf.cd4f28ac64e5acb35bc2b00f778ca750.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/Video2_181_jpg.rf.3bf047facfde97e452509c0387cfe706.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/00350_jpg.rf.068d22e2863af0ada2b76943516ffc21.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/Video4_26_jpg.rf.ecc06ff11eb72c34a009b44e0a6637c5.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/img13_png.rf.8cd0a61d04224e2af2e75b4c350731a4.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/Video4_25_jpg.rf.5e09ce9ae6a654848aa1e24baff781d5.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/00000284_jpg.rf.a2843416db4afceaed0d965d86a458df.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/Video1_53_jpg.rf.c1e26f0726447ab613c46dfdd7acefeb.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/11_jpg.rf.c614e7b2883a41a98f657ffd6ba43337.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/Obreros_valmetro_jpg.rf.0950513789bdc2306054aed458a3b881.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/obrero-de-la-construccion-con-chaleco-seguridad-y-casco-sobre-fondo-azul-sonriendo-apuntando-cabeza-un-trabajador-asiatico-192391386_jpg.rf.43cb8847e8ecc271c538de597a4b3b92.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/00000039_jpg.rf.cfa73aa1dc777b7a57e49c6159ea1f77.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/IMG-20230705-WA0021_jpg.rf.205a70b61a004dc8ae35fea65180be6d.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/190789411-end-day-wrap-during-covid19-pa_jpg.rf.c08a19c48bdc71687c3f2c36bd86f2a6.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/00000059_jpg.rf.0bb4fb911862ccd28c4251b43a9ca8d1.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/IMG-20230805-WA0021_jpg.rf.fc4583a0741b116b84618a8762610a62.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/00000266_jpg.rf.a03fb82fdf8d2e6e5e9d40353de6adaf.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/00000068_jpg.rf.3481ab607fe6b536557f255ab1620930.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/38_jpg.rf.105d1be1b914ff2a2d383bda4ac353a6.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/WhatsApp-Image-2023-10-03-at-14-38-06_fbf34fe5_jpg.rf.7584309a5bf8b6fbf362e48ddc5794a0.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/160267228-switzerland-1971-workers-build_jpg.rf.2ba667807453054e22828325a39465d6.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/WhatsApp-Image-2023-09-28-at-09-46-28_20055c47_jpg.rf.e1d9bebe5c3acf88c3cd751547dd8c45.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/00000040_jpg.rf.5b4af4c8a83c656a20a954a7753542b3.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/images-50-.rf.f15e8a56aa32bea48fc19634c99924ce.xml',
#  '/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test/AightSird0542_jpg.rf.5ffa4e1af8761a9367fb2b0fbd27a7aa.xml']

# %%
# step-2: read xml files
# from each xml file we need to extract
# filename, size(width, height), object(name, xmin, xmax, ymin, ymax)
def extract_text(filename):
    tree = et.parse(filename)
    root = tree.getroot()

    # extract filename
    image_name = root.find('filename').text
    # width and height of the image
    width = root.find('size').find('width').text
    height = root.find('size').find('height').text
    objs = root.findall('object')
    parser = []
    for obj in objs:
        name = obj.find('name').text
        bndbox = obj.find('bndbox')
        xmin = bndbox.find('xmin').text
        xmax = bndbox.find('xmax').text
        ymin = bndbox.find('ymin').text
        ymax = bndbox.find('ymax').text
        parser.append([image_name, width, height, name,xmin,xmax,ymin,ymax])
        
    return parser

# %%
parser_all = list(map(extract_text,xmlfiles))

# %%
data = reduce(lambda x, y : x+y,parser_all)

# %%
df = pd.DataFrame(data,columns = ['filename','width','height','name','xmin','xmax','ymin','ymax'])

# %%
df.head()
# Out:
#                                             filename width height  name xmin  \
# 0     36_jpg.rf.e4757f0ab57054029ade0bb5d666673a.jpg   292    494   hat   94
# 1     36_jpg.rf.e4757f0ab57054029ade0bb5d666673a.jpg   292    494  vest   29
# 2     36_jpg.rf.e4757f0ab57054029ade0bb5d666673a.jpg   292    494  vest    1
# 3  KakaoTalk_20221018_001425789_07_jpg.rf.afa1e8a...   640    640   hat  101
# 4  KakaoTalk_20221018_001425789_07_jpg.rf.afa1e8a...   640    640  vest  196
#
#   xmax ymin ymax
# 0  229    1  139
# 1  293  139  442
# 2   50  217  495
# 3  196  256  391
# 4  456  209  379

# %%
df.shape
# Out:
# (209, 8)

# %%
df['name'].value_counts()
# Out:
# name
# hat        81
# vest       73
# no vest    31
# no hat     24
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  209 non-null    object
#  1   width     209 non-null    object
#  2   height    209 non-null    object
#  3   name      209 non-null    object
#  4   xmin      209 non-null    object
#  5   xmax      209 non-null    object
#  6   ymin      209 non-null    object
#  7   ymax      209 non-null    object
# dtypes: object(8)
# memory usage: 13.2+ KB

# %%
# type conversion
cols = ['width','height','xmin','xmax','ymin','ymax']
df[cols] = df[cols].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  209 non-null    object
#  1   width     209 non-null    int64
#  2   height    209 non-null    int64
#  3   name      209 non-null    object
#  4   xmin      209 non-null    int64
#  5   xmax      209 non-null    int64
#  6   ymin      209 non-null    int64
#  7   ymax      209 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 13.2+ KB

# %%
# center x, center y
df['center_x'] = ((df['xmax']+df['xmin'])/2)/df['width']
df['center_y'] = ((df['ymax']+df['ymin'])/2)/df['height']
# w 
df['w'] = (df['xmax']-df['xmin'])/df['width']
# h 
df['h'] = (df['ymax']-df['ymin'])/df['height']

# %%
df.head()
# Out:
#                                             filename  width  height  name  \
# 0     36_jpg.rf.e4757f0ab57054029ade0bb5d666673a.jpg    292     494   hat
# 1     36_jpg.rf.e4757f0ab57054029ade0bb5d666673a.jpg    292     494  vest
# 2     36_jpg.rf.e4757f0ab57054029ade0bb5d666673a.jpg    292     494  vest
# 3  KakaoTalk_20221018_001425789_07_jpg.rf.afa1e8a...    640     640   hat
# 4  KakaoTalk_20221018_001425789_07_jpg.rf.afa1e8a...    640     640  vest
#
#    xmin  xmax  ymin  ymax  center_x  center_y         w         h
# 0    94   229     1   139  0.553082  0.141700  0.462329  0.279352
# 1    29   293   139   442  0.551370  0.588057  0.904110  0.613360
# 2     1    50   217   495  0.087329  0.720648  0.167808  0.562753
# 3   101   196   256   391  0.232031  0.505469  0.148438  0.210938
# 4   196   456   209   379  0.509375  0.459375  0.406250  0.265625

# %%
images = df['filename'].unique()

# %%
len(images)
# Out:
# 44

# %%
# 80% train and 20% test
img_df = pd.DataFrame(images,columns=['filename'])
img_train = tuple(img_df.sample(frac=0.8)['filename']) # shuffle and pick 80% of images

# %%
img_test = tuple(img_df.query(f'filename not in {img_train}')['filename']) # take rest 20% images

# %%
len(img_train), len(img_test)
# Out:
# (35, 9)

# %%
train_df = df.query(f'filename in {img_train}')
test_df = df.query(f'filename in {img_test}')

# %%
train_df.head()
# Out:
#                                             filename  width  height  name  \
# 0     36_jpg.rf.e4757f0ab57054029ade0bb5d666673a.jpg    292     494   hat
# 1     36_jpg.rf.e4757f0ab57054029ade0bb5d666673a.jpg    292     494  vest
# 2     36_jpg.rf.e4757f0ab57054029ade0bb5d666673a.jpg    292     494  vest
# 5  feliz-administrador-de-almacen-pie-en-una-fabr...    800     550   hat
# 6  feliz-administrador-de-almacen-pie-en-una-fabr...    800     550  vest
#
#    xmin  xmax  ymin  ymax  center_x  center_y         w         h
# 0    94   229     1   139  0.553082  0.141700  0.462329  0.279352
# 1    29   293   139   442  0.551370  0.588057  0.904110  0.613360
# 2     1    50   217   495  0.087329  0.720648  0.167808  0.562753
# 5   288   567     1   191  0.534375  0.174545  0.348750  0.345455
# 6   230   607   228   551  0.523125  0.708182  0.471250  0.587273

# %%
test_df.head()
# Out:
#                                              filename  width  height  name  \
# 3   KakaoTalk_20221018_001425789_07_jpg.rf.afa1e8a...    640     640   hat
# 4   KakaoTalk_20221018_001425789_07_jpg.rf.afa1e8a...    640     640  vest
# 13  00000206_jpg.rf.3421fc09104c3afc6e8cbb3bc5a9a8...    256     256   hat
# 14  00000206_jpg.rf.3421fc09104c3afc6e8cbb3bc5a9a8...    256     256   hat
# 15  images-31-.rf.0211bd26e06fb898b7c48989199ceabd...    474     640   hat
#
#     xmin  xmax  ymin  ymax  center_x  center_y         w         h
# 3    101   196   256   391  0.232031  0.505469  0.148438  0.210938
# 4    196   456   209   379  0.509375  0.459375  0.406250  0.265625
# 13   178   212    53    87  0.761719  0.273438  0.132812  0.132812
# 14   172   216    82   153  0.757812  0.458984  0.171875  0.277344
# 15     4   276     1   206  0.295359  0.161719  0.573840  0.320312

# %%
# label encoding
def label_encoding(x):
    labels = {'hat':0, 'vest':1, 'no hat':2, 'no vest':3}
    return labels[x]

# %%
train_df['id'] = train_df['name'].apply(label_encoding)
test_df['id'] = test_df['name'].apply(label_encoding)

# %%
train_df.head(10)
# Out:
#                                              filename  width  height     name  \
# 0      36_jpg.rf.e4757f0ab57054029ade0bb5d666673a.jpg    292     494      hat
# 1      36_jpg.rf.e4757f0ab57054029ade0bb5d666673a.jpg    292     494     vest
# 2      36_jpg.rf.e4757f0ab57054029ade0bb5d666673a.jpg    292     494     vest
# 5   feliz-administrador-de-almacen-pie-en-una-fabr...    800     550      hat
# 6   feliz-administrador-de-almacen-pie-en-una-fabr...    800     550     vest
# 7   WhatsApp-Image-2023-10-10-at-11-18-26_a11a66e1...   1600    1200   no hat
# 8   WhatsApp-Image-2023-10-10-at-11-18-26_a11a66e1...   1600    1200  no vest
# 9   WhatsApp-Image-2023-10-10-at-11-18-26_a11a66e1...   1600    1200      hat
# 10  WhatsApp-Image-2023-10-10-at-11-18-26_a11a66e1...   1600    1200      hat
# 11  WhatsApp-Image-2023-10-10-at-11-18-26_a11a66e1...   1600    1200     vest
#
#     xmin  xmax  ymin  ymax  center_x  center_y         w         h  id
# 0     94   229     1   139  0.553082  0.141700  0.462329  0.279352   0
# 1     29   293   139   442  0.551370  0.588057  0.904110  0.613360   1
# 2      1    50   217   495  0.087329  0.720648  0.167808  0.562753   1
# 5    288   567     1   191  0.534375  0.174545  0.348750  0.345455   0
# 6    230   607   228   551  0.523125  0.708182  0.471250  0.587273   1
# 7   1026  1094   476   534  0.662500  0.420833  0.042500  0.048333   2
# 8    979  1054   521   669  0.635312  0.495833  0.046875  0.123333   3
# 9   1491  1601   404   494  0.966250  0.374167  0.068750  0.075000   0
# 10  1428  1494   454   523  0.913125  0.407083  0.041250  0.057500   0
# 11  1404  1489   511   654  0.904062  0.485417  0.053125  0.119167   1

# %%
import os
from shutil import move

# %%
train_folder = '/home/cpow/Desktop/eageleeyes/dataset/pascal/train'
test_folder = '/home/cpow/Desktop/eageleeyes/dataset/pascal/test'


os.mkdir(train_folder)
os.mkdir(test_folder)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[30], line 5
#       1 train_folder = '/home/cpow/Desktop/eageleeyes/dataset/pascal/train'
#       2 test_folder = '/home/cpow/Desktop/eageleeyes/dataset/pascal/test'
# ----> 5 os.mkdir(train_folder)
#       6 os.mkdir(test_folder)
#
# FileExistsError: [Errno 17] File exists: '/home/cpow/Desktop/eageleeyes/dataset/pascal/train'

# %%
cols = ['filename','id','center_x','center_y', 'w', 'h']
groupby_obj_train = train_df[cols].groupby('filename')
groupby_obj_test = test_df[cols].groupby('filename')

# %%
#groupby_obj_train.get_group('000009.jpg').set_index('filename').to_csv('sample.txt',index=False,header=False)
# save each image in train/test folder and repective labels in .txt
def save_data(filename, folder_path, group_obj):
    # move image
    src = os.path.join('/home/cpow/Desktop/eageleeyes/dataset/pascal/labeled_test',filename)
    dst = os.path.join(folder_path,filename)
    move(src,dst) # move image to the destination folder
    
    # save the labels
    text_filename = os.path.join(folder_path,
                                 os.path.splitext(filename)[0]+'.txt')
    group_obj.get_group(filename).set_index('filename').to_csv(text_filename,sep=' ',index=False,header=False)

# %%
filename_series = pd.Series(groupby_obj_train.groups.keys())

# %%
filename_series.apply(save_data,args=(train_folder,groupby_obj_train))
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# 23    None
# 24    None
# 25    None
# 26    None
# 27    None
# 28    None
# 29    None
# 30    None
# 31    None
# 32    None
# 33    None
# 34    None
# dtype: object

# %%
filename_series_test = pd.Series(groupby_obj_test.groups.keys())
filename_series_test.apply(save_data,args=(test_folder,groupby_obj_test))
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# 5    None
# 6    None
# 7    None
# 8    None
# dtype: object
