# %%
import os
os.chdir('drive/MyDrive/yolo_training')

# %%
ls
# Out:
# yolo_training.ipynb  yolov5/

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17270, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 17270 (delta 0), reused 0 (delta 0), pack-reused 17269 (from 2)
# Receiving objects: 100% (17270/17270), 16.10 MiB | 10.51 MiB/s, done.
# Resolving deltas: 100% (11855/11855), done.
# Updating files: 100% (146/146), done.

# %%
os.chdir('yolov5')

# %%
ls
# Out:
# benchmarks.py    data/      hubconf.py      README.md         train.py
# CITATION.cff     datasets/  LICENSE         README.zh-CN.md   tutorial.ipynb
# classify/        detect.py  models/         requirements.txt  utils/
# CONTRIBUTING.md  export.py  pyproject.toml  segment/          val.py

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 33.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 27.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 18.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 66.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 921.9/921.9 kB 49.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !python train.py --data data.yaml --cfg yolov5s.yaml --batch-size 8 --name Model --epochs 50
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-02-28 12:12:29.874862: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740744749.896978    4904 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740744749.903846    4904 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# ...

# %%
# !python export.py --weights /content/drive/MyDrive/yolo_training/yolov5/runs/train/Model4/weights/best.pt --include torchscript onnx  tflite tfjs
# Out:
# export: data=data/coco128.yaml, weights=['/content/drive/MyDrive/yolo_training/yolov5/runs/train/Model4/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=False, mlmodel=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'onnx', 'tflite', 'tfjs']
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from /content/drive/MyDrive/yolo_training/yolov5/runs/train/Model4/weights/best.pt with output shape (1, 25200, 9) (13.7 MB)
#
# TorchScript: starting export with torch 2.5.1+cu124...
# ...

# %%
# !python export.py --weights /content/drive/MyDrive/yolo_training/yolov5/runs/train/Model4/weights/best.pt --include torchscript onnx
# Out:
# export: data=data/coco128.yaml, weights=['/content/drive/MyDrive/yolo_training/yolov5/runs/train/Model4/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=False, mlmodel=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'onnx']
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from /content/drive/MyDrive/yolo_training/yolov5/runs/train/Model4/weights/best.pt with output shape (1, 25200, 9) (13.7 MB)
#
# TorchScript: starting export with torch 2.5.1+cu124...
# TorchScript: export success ✅ 2.5s, saved as /content/drive/MyDrive/yolo_training/yolov5/runs/train/Model4/weights/best.torchscript (27.2 MB)
#
# ...

# %%
# !python export.py --weights /content/drive/MyDrive/yolo_training/yolov5/runs/train/Model4/weights/best.pt --include torchscript  tflite
# Out:
# export: data=data/coco128.yaml, weights=['/content/drive/MyDrive/yolo_training/yolov5/runs/train/Model4/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=False, mlmodel=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'tflite']
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from /content/drive/MyDrive/yolo_training/yolov5/runs/train/Model4/weights/best.pt with output shape (1, 25200, 9) (13.7 MB)
#
# TorchScript: starting export with torch 2.5.1+cu124...
# TorchScript: export success ✅ 2.6s, saved as /content/drive/MyDrive/yolo_training/yolov5/runs/train/Model4/weights/best.torchscript (27.2 MB)
# ...

# %%
# !python export.py --weights /content/drive/MyDrive/yolo_training/yolov5/runs/train/Model4/weights/best.pt --include torchscript  tfjs
# Out:
# export: data=data/coco128.yaml, weights=['/content/drive/MyDrive/yolo_training/yolov5/runs/train/Model4/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=False, mlmodel=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'tfjs']
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from /content/drive/MyDrive/yolo_training/yolov5/runs/train/Model4/weights/best.pt with output shape (1, 25200, 9) (13.7 MB)
#
# TorchScript: starting export with torch 2.5.1+cu124...
# TorchScript: export success ✅ 2.6s, saved as /content/drive/MyDrive/yolo_training/yolov5/runs/train/Model4/weights/best.torchscript (27.2 MB)
# ...
